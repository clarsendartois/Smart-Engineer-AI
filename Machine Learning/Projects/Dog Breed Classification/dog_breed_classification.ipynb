# %% [markdown]
# <p align="center">
#   <a href="https://colab.research.google.com/github/clarsendartois/Smart-Engineer-AI/blob/main/Machine%20Learning/Projects/Dog%20Breed%20Classification/dog_breed_classification.ipynb" target="_blank">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
#   </a>
# </p>
#
# # 📶 **A Step-by-Step Field Guide for Building Machine Learning Projects: Reusable Blueprint**
#
# > _ℹ️ This template provides a structured approach to undertaking any Machine Learning project, from initial problem definition to deployment and continuous monitoring. Use this as your personal blueprint to ensure no critical step is missed. Fill in the blank spaces with your project-specific details and code!_ ✨
#
# <center>
#   <a href="https://www.youtube.com/watch?v=astmDMRHgds" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/jpeg;base64,..." height="188" width="336">
#   </a>
# </center>
#
# ---
#
# # **General Best Practices and Considerations ✨**
# * **Version Control:** ↔️ Use Git for code, data, and model versions.
#   * **Repo Link:** [Link to your GitHub/GitLab repo]
# * **Documentation:** 📝 Document every step, from problem definition to deployment details.
#   * **Documentation Location:** [e.g., README.md, Confluence page]
# * **Reproducibility:** ♻️ Ensure your experiments and results can be reproduced by others.
#   * **How:** [e.g., "Using requirements.txt for dependencies, fixed random seeds."]
# * **Collaboration:** 🤝 Work effectively in a team, leveraging tools and clear communication.
#   * **Team Communication Tools:** [e.g., Slack, Microsoft Teams]
# * **Ethical Considerations:** 🤔 Address potential biases in data and models, fairness, and privacy.
#   * **Mitigation Strategies:** [e.g., "Fairness metrics checked for disparate impact on demographic groups."]
# * **Cost Management:** 💲 Be mindful of computational costs, especially in cloud environments.
#   * **Cost Optimization:** [e.g., "Using spot instances for training, optimizing inference latency."]
# * **Iterative Process:** 🔄 Machine learning projects are often iterative. Be prepared to revisit earlier phases as new insights emerge.
#
# ---

# %% [markdown]
# # 📚 **Project Title:**
# **Dog Breed Classification using Transfer Learning and TensorFlow**
#
# # 🎯 **Project Goal:**
# **To build an image classification model that accurately identifies the breed of a dog from an image, leveraging transfer learning with a pre-trained deep learning model from TensorFlow.**
#
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## ***Phase 1: Problem Definition and Understanding*** 💡
#
# > _This initial phase is arguably the most critical. A clear understanding of the problem ensures your efforts are well-directed and aligned with business goals._
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 💡**1.1 Define the Problem Clearly**
#
# </div>

# %% [markdown]
# * **What exactly are you trying to solve?**
#   * Given an image of a dog, classify it into one of 'N' predefined dog breeds.
# * **Is it a classification, regression, clustering, or a different type of problem?**
#   * Multi-class Image Classification.
# * **What are the inputs and desired outputs?**
#   * ***Inputs***: Dog images (JPEG, PNG format).
#   * ***Outputs***: Predicted dog breed label (e.g., 'Golden Retriever', 'Poodle') and a confidence score for each breed.
#
# #### **Your Project Details**:
#
# * **Problem Statement:** To develop a robust image classification model capable of distinguishing between various dog breeds in photographic images.
# * **Problem Type:** Multi-class Classification (specifically, image classification)
# * **Inputs & Outputs**:
#   * ***Inputs:*** Digital images of dogs (e.g., image_0001.jpg). Images will need to be preprocessed to a consistent size and format (e.g., 224x224 pixels, 3 channels).
#   * ***Outputs:*** A categorical label representing the predicted dog breed (e.g., 'Labrador_Retriever', 'German_Shepherd') and a probability distribution over all possible breeds.
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 💡**1.2 Establish Project Goals and Success Metrics**
#
# </div>

# %% [markdown]
# * **What does "success" look like for this project?**
#   * Achieving a top-1 accuracy of at least 85% on unseen images.
#   * Achieving a top-5 accuracy of at least 95% (meaning the correct breed is among the top 5 predictions).
#   * Reasonable inference speed (e.g., &lt; 100ms per image on a GPU).urn rate by 5% over 3 months.*
# * **How will you measure performance?**
#   * Metrics: Top-1 Accuracy, Top-5 Accuracy, F1-score (macro average if classes are balanced, weighted if imbalanced), Confusion Matrix.
#
# #### **Your Project Details:**
#
# * **Quantifiable Success Metrics:**
#   * [Achieve Top-1 Accuracy
# geq0.85 on the test set.
#   * Achieve Top-5 Accuracy
# geq0.95 on the test set.
#   * Inference time per image
# leq100ms (on a specific hardware).
# * **Business KPIs Impacted:** Enhanced user experience for a dog identification app, improved efficiency for animal shelters in breed identification, support for veterinary diagnostics.
# -----

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 💡**1.3 Identify Data Requirements and Sources**
#
# </div>

# %% [markdown]
# * **What data do you need?**
#   * A large dataset of dog images, clearly labeled with their respective breeds.
# * **Where will it come from?**
#   * Commonly used datasets: Stanford Dogs Dataset, ImageNet (subset related to dogs), Kaggle Dog Breed Identification Challenge.
#   * Alternative: Curated datasets from pet associations or user-generated content platforms.
# * **Are there any privacy or regulatory constraints (e.g., GDPR, HIPAA)?**
#   * Generally low for dog images, but if images contain identifiable human faces or sensitive backgrounds, then privacy becomes a concern. For public datasets, this is usually handled.
#
# #### **Your Project Details:**
#
# * **Required Data & Sources:**
#     * Stanford Dogs Dataset (120 breeds, $\sim$20,580 images). Accessible via TensorFlow Datasets (TFDS) or direct download.
#     * Data Source 2 (Optional for expansion): Images scraped from Flickr/Google Images (requires careful licensing and manual labeling/verification).
# * **Privacy/Regulatory Considerations:** Stanford Dogs Dataset is publicly available for research. No direct human privacy concerns with this dataset.
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 💡**1.4 Assess Feasibility and Resources**
#
# </div>

# %% [markdown]
# * **Do you have the necessary data, computational resources (GPUs, cloud platforms), and expertise within the team?**
#   * Data: Stanford Dogs Dataset is suitable. Computational: Requires GPU for efficient training (Google Colab Pro GPU or equivalent). Expertise: Familiarity with Python, TensorFlow/Keras, and image processing concepts.
# * **What are the timelines and budget constraints?**
#   * Timeline: 6 weeks for initial model development and evaluation. Budget: Moderate (reliant on cloud GPU services like Colab Pro or AWS/GCP credits).
#
# #### **Your Project Details:**
#
# * **Available Resources:** Python (TensorFlow, Keras, OpenCV, Matplotlib, Seaborn), Google Colab (with GPU runtime enabled), Jupyter Notebook environment.
# * **Timelines & Budget:** 6-week initial development phase. Moderate budget, primarily for GPU usage on cloud platforms.
# -----

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## ***Phase 2: Data Collection and Preparation*** 📊
#
# > _This phase focuses on acquiring, cleaning, and transforming the data into a usable format for machine learning models. It often consumes a significant portion of project time._
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 📊 **2.1 Data Collection**
#
# </div>

# %% [markdown]
# * **Gather data from identified sources.**
# * **Ensure data quantity and quality are sufficient.**
#
# #### **Your Project Code & Details:**

# %%
# Import necessary libraries for data collection
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the Stanford Dogs dataset using TensorFlow Datasets
# The 'as_supervised=True' option makes the dataset yield (image, label) pairs.
# with_info=True provides metadata about the dataset, like number of classes.
try:
    (ds_train_raw, ds_val_raw, ds_test_raw), ds_info = tfds.load(
        'stanford_dogs',
        split=['train', 'test[50%:]', 'test[:50%]'], # Example split: use part of test as validation
        shuffle_files=True,
        as_supervised=True,
        with_info=True
    )
    num_classes = ds_info.features['label'].num_classes
    class_names = ds_info.features['label'].names
    print(f"Dataset loaded. Number of classes: {num_classes}")
    print(f"Train samples: {ds_info.splits['train'].num_examples}")
    print(f"Validation samples: {ds_info.splits['test[50%:]'].num_examples}") # Adjust split name if necessary
    print(f"Test samples: {ds_info.splits['test[:50%]'].num_examples}") # Adjust split name if necessary

except Exception as e:
    print(f"Error loading Stanford Dogs dataset: {e}")
    print("Please ensure you have internet access and TFDS is configured correctly.")

# Display a sample image
for image, label in ds_train_raw.take(1):
    print(f"Image shape: {image.shape}, Label: {label.numpy()} ({class_names[label.numpy()]})")
    plt.imshow(image)
    plt.title(class_names[label.numpy()])
    plt.axis('off')
    plt.show()
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/stanford_dogs/0.2.0 has no dataset_info.json
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/stanford_dogs/incomplete.8V5XVN_0.2.0/stanford_dogs-train.tfrecord*...:   …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/stanford_dogs/incomplete.8V5XVN_0.2.0/stanford_dogs-test.tfrecord*...:   0…
# Dataset stanford_dogs downloaded and prepared to /root/tensorflow_datasets/stanford_dogs/0.2.0. Subsequent calls will reuse this data.
# Dataset loaded. Number of classes: 120
# Train samples: 12000
# Validation samples: 4290
# Test samples: 4290
# ...

# %% [markdown]
# ---
# * **Data Source:** Stanford Dogs Dataset from TensorFlow Datasets.
# * **Quantity:** Approx. 12,000 training images, $\sim$4,200 validation images, $\sim$4,200 test images across 120 breeds.

# %% [markdown]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 📊 **2.2 Data Cleaning**
#
# </div>

# %% [markdown]
# * **Handle Missing Values:** (Not applicable for image datasets in the traditional sense).
# * **Remove Duplicates:** (Handled by dataset creators, but can be an issue with custom datasets).
# * **Correct Inconsistent Data:** Ensure image formats are consistent, handle corrupted images.
# * **Deal with Outliers:** (e.g., highly distorted images, images not containing dogs).
#
# #### **Your Project Code & Details:**

# %%
# For image datasets, 'cleaning' primarily involves robust loading and preprocessing.
# TFDS datasets are usually clean. Corrupted files are rare.
# If using custom image folders, you might add checks:
# from PIL import Image
# import os
#
# def check_image_integrity(filepath):
#     try:
#         img = Image.open(filepath)
#         img.verify() # Verify image integrity
#         return True
#     except Exception as e:
#         print(f"Corrupted image: {filepath} - {e}")
#         return False

print("Data cleaning steps are primarily integrated into preprocessing for image datasets.")
print("TFDS datasets are generally pre-cleaned and reliable.")

# No explicit cleaning code here as TFDS handles most of it,
# but if downloading raw images, integrity checks are crucial.
# Out:
# Data cleaning steps are primarily integrated into preprocessing for image datasets.
# TFDS datasets are generally pre-cleaned and reliable.

# %% [markdown]
# * **Summary of Cleaning Actions:**  Relying on the robustness and pre-cleaning of the TensorFlow Datasets (stanford_dogs) source. If using custom datasets, explicit checks for corrupted images and non-dog images would be implemented.
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 📊 **2.3 Data Integration (if necessary)**
#
# </div>

# %% [markdown]
# * **Combine data from multiple sources.**
# * **Ensure consistent keys and formats.**
#
# #### **Your Project Code & Details:**

# %%
# For this project, we are using a single dataset.
# If integrating, ensure consistent labeling and image dimensions.
# This would involve combining tf.data.Dataset objects.

# Example: If you had a second dataset, you might do:
# ds_train_combined = ds_train_raw.concatenate(ds_train_raw_2)

print("No data integration required for this project as a single TFDS dataset is used.")
# Out:
# No data integration required for this project as a single TFDS dataset is used.

# %% [markdown]
# * **Integration Strategy:** No data integration performed as the project relies on a single, comprehensive dataset (Stanford Dogs Dataset).
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 📊 **2.4 Data Transformation**
#
# </div>

# %% [markdown]
# * **Feature Scaling:** Normalize pixel values (e.g., to [0, 1] or [-1, 1]). numerical features.
# * **Encoding Categorical Variables:**  Labels are already integers, often converted to one-hot for classification.
# * **Feature Engineering:** Image augmentations (e.g., rotation, flip, zoom) are crucial for deep learning to prevent overfitting. Resizing images.
#
# #### **Your Project Code & Details:**

# %%
# Define target image size and batch size
IMG_SIZE = (160, 160) # Standard input size for many pre-trained models (e.g., MobileNetV2, VGG16)
BATCH_SIZE = 32

# Preprocessing function for training data (includes augmentation)
def preprocess_train(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32) / 255.0 # Normalize pixel values to [0, 1]
    image = tf.image.random_flip_left_right(image)
    # image = tf.image.random_zoom(image, zoom_factor=(0.8, 1.2)) # Example augmentation
    # Replacing random_zoom with random_crop and resize to achieve a similar effect
    # Determine crop size based on zoom_factor (e.g., 0.8 means crop to 80% of size)
    zoom_min = 0.8
    zoom_max = 1.2
    # Calculate the crop size such that resizing it back to IMG_SIZE simulates zoom
    # For zoom_factor z, the crop needs to be 1/z of the original size
    # So for zoom_factor (0.8, 1.2), the crop percentage is (1/1.2, 1/0.8) ≈ (0.83, 1.25)
    # We want a *random crop* of a smaller size and then resize it back to IMG_SIZE
    # Let's simplify for now and use random_crop with a fixed size and then resize
    # A zoom of 0.8 means the image is scaled up, so we're cropping a smaller area
    # A zoom of 1.2 means the image is scaled down, so we're cropping a larger area (which isn't how random_crop works)
    # A better simulation of random_zoom using available functions involves random crops
    # If zoom_factor is (a, b) where a < 1 and b > 1:
    # If random_zoom < 1, it zooms in (crops a smaller area)
    # If random_zoom > 1, it zooms out (crops a larger area - not possible with random_crop)
    # A simpler approach for random zooming *in* (zoom_factor < 1 for effect)
    # is to randomly crop a fraction of the image and then resize it back.
    # Let's implement zoom-in augmentation (equivalent to zoom_factor < 1)
    scale_factor = tf.random.uniform([], zoom_min, 1.0) # Random scale between zoom_min and 1
    new_height = tf.cast(tf.cast(IMG_SIZE[0], tf.float32) * scale_factor, tf.int32)
    new_width = tf.cast(tf.cast(IMG_SIZE[1], tf.float32) * scale_factor, tf.int32)
    # Ensure crop size is not larger than the image size after initial resize
    crop_height = tf.minimum(new_height, IMG_SIZE[0])
    crop_width = tf.minimum(new_width, IMG_SIZE[1])
    image = tf.image.random_crop(image, size=[crop_height, crop_width, 3])
    image = tf.image.resize(image, IMG_SIZE) # Resize back to original target size


    image = tf.image.random_brightness(image, max_delta=0.2)
    # label = tf.one_hot(label, num_classes) # One-hot encode labels if loss function requires it
    return image, label

# Preprocessing function for validation/test data (no augmentation)
def preprocess_val_test(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32) / 255.0 # Normalize pixel values to [0, 1]
    # label = tf.one_hot(label, num_classes) # One-hot encode labels
    return image, label

# Apply transformations and create batched datasets
AUTOTUNE = tf.data.AUTOTUNE

ds_train = ds_train_raw.map(preprocess_train, num_parallel_calls=AUTOTUNE)
ds_train = ds_train.cache().shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

ds_val = ds_val_raw.map(preprocess_val_test, num_parallel_calls=AUTOTUNE)
ds_val = ds_val.cache().batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

ds_test = ds_test_raw.map(preprocess_val_test, num_parallel_calls=AUTOTUNE)
ds_test = ds_test.cache().batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

print("\nData transformation setup complete. Datasets are batched and preprocessed.")
# Out:
# Data transformation setup complete. Datasets are batched and preprocessed.

# %% [markdown]
# * **Transformation Summary:**
#   * Image Resizing: All images resized to 224
# times224 pixels.
#   * Pixel Normalization: Pixel values scaled to the range [0,1].
#   * Image Augmentation (Training): Applied random horizontal flips, random zoom, and random brightness changes to increase data diversity and prevent overfitting.
#   * Label Encoding: Labels are integers; will be implicitly handled by SparseCategoricalCrossentropy loss. If using CategoricalCrossentropy, labels would be one-hot encoded.
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 📊 **2.5 Data Splitting**
#
# </div>

# %% [markdown]
# * **Divide the dataset into training, validation (optional but recommended), and test sets.**
# * **Maintain class distribution using stratification if dealing with imbalanced datasets.**
#
# #### **Your Project Code & Details:**

# %%
# Data splitting is handled directly by tfds.load() using split arguments.
# For Stanford Dogs, the 'test' split was divided into two halves for validation and test.
# TFDS handles potential stratification within its splits for many datasets.

print("Data splitting handled by TensorFlow Datasets during initial load.")
print(f"Number of training batches: {len(ds_train)}")
print(f"Number of validation batches: {len(ds_val)}")
print(f"Number of test batches: {len(ds_test)}")

# Verify the output shapes of the first batch
# for images, labels in ds_train.take(1):
#     print(f"Train batch images shape: {images.shape}")
#     print(f"Train batch labels shape: {labels.shape}")
# Out:
# Data splitting handled by TensorFlow Datasets during initial load.
# Number of training batches: 375
# Number of validation batches: 135
# Number of test batches: 135

# %% [markdown]
# * **Splitting Strategy:** TensorFlow Datasets split stanford_dogs into a train split and a test split. The test split was further divided to create a dedicated validation set (first 50% of original test) and a test set (remaining 50% of original test).
# * **Class Distribution:** TFDS typically ensures balanced class distribution across splits for such datasets.
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## ***Phase 3: Exploratory Data Analysis (EDA)*** 🔎
#
# > _EDA is crucial for understanding the data's characteristics, identifying patterns, and gaining insights that inform model selection and feature engineering._
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🔎 **3.1 Understand Data Distribution**
#
# </div>

# %% [markdown]
# * **Sample images, label distribution.**
#
# #### **Your Project Code & Details:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize sample images with their labels
plt.figure(figsize=(10, 10))
for i, (image, label) in enumerate(ds_train_raw.take(9)): # Use raw dataset for original image sizes
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy())
    plt.title(class_names[label.numpy()])
    plt.axis("off")
plt.suptitle("Sample Images from Training Dataset")
plt.show()

# Get label distribution (can be done by iterating through the dataset)
# This might be computationally intensive for very large datasets,
# but for Stanford Dogs, it's feasible.
label_counts_train = {}
for _, label in ds_train_raw.as_numpy_iterator():
    label_name = class_names[label]
    label_counts_train[label_name] = label_counts_train.get(label_name, 0) + 1

label_counts_df = pd.DataFrame(label_counts_train.items(), columns=['Breed', 'Count']).sort_values('Count', ascending=False)
print("\nTop 10 Dog Breeds by Count in Training Set:")
print(label_counts_df.head(10))

plt.figure(figsize=(12, 6))
sns.barplot(x='Count', y='Breed', data=label_counts_df.head(10), palette='viridis')
plt.title('Distribution of Top 10 Dog Breeds in Training Set')
plt.xlabel('Number of Images')
plt.ylabel('Dog Breed')
plt.show()
# Out:
# Top 10 Dog Breeds by Count in Training Set:
#                           Breed  Count
# 0       n02101006-gordon_setter    100
# 1       n02110627-affenpinscher    100
# 2     n02094114-norfolk_terrier    100
# 3             n02091134-whippet    100
# 4  n02091467-norwegian_elkhound    100
# 5              n02088364-beagle    100
# 6       n02109525-saint_bernard    100
# 7      n02096437-dandie_dinmont    100
# 8        n02100877-irish_setter    100
# 9            n02110063-malamute    100
# <ipython-input-6-cd2a3755d20a>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='Breed', data=label_counts_df.head(10), palette='viridis')

# %% [markdown]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🔎 **3.2 Identify Relationships Between Variables**
#
# </div>

# %% [markdown]
# * **(Less applicable for image classification, but could involve looking at image metadata if available).**
#
# #### **Your Project Notes:**
# * For image classification, traditional "relationships between variables" (like numerical feature correlations) are less direct.
# * Insights: The dataset has 120 classes, and the distribution appears relatively balanced, with no extreme class imbalance, which is good for multi-class classification. Some breeds might have slightly more images than others, but generally, it's uniform enough not to require specific over/under-sampling strategies for the first pass.
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🔎 **3.3 Visualize Data**
#
# </div>

# %% [markdown]
# * **Explore images by class, analyze image characteristics (e.g., size, aspect ratio distribution if not uniform).**
#
# #### **Your Project Code & Details:**

# %%
# Visualize images after preprocessing/augmentation (first batch)
for images, labels in ds_train.take(1):
    plt.figure(figsize=(12, 12))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy())
        plt.title(class_names[labels[i].numpy()])
        plt.axis("off")
    plt.suptitle("Sample Images After Preprocessing/Augmentation")
    plt.show()

# (Optional) Check aspect ratio distribution if images weren't uniformly sized originally
# from PIL import Image
# import os

# image_paths = tfds.as_numpy(ds_info.splits['train'].file_paths) # This might not be directly available for all TFDS
# aspect_ratios = []
# for path in image_paths:
#     try:
#         with Image.open(path) as img:
#             aspect_ratios.append(img.width / img.height)
#     except Exception:
#         pass # Skip corrupted images

# if aspect_ratios:
#     plt.figure(figsize=(8, 6))
#     sns.histplot(aspect_ratios, bins=50, kde=True)
#     plt.title('Distribution of Image Aspect Ratios (Raw Data)')
#     plt.xlabel('Aspect Ratio (Width/Height)')
#     plt.ylabel('Count')
#     plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.13798456..0.7555841].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.053424254..1.0501175].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07902299..0.8637893].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07279602..0.9138552].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1496542..0.8474793].
# ...

# %% [markdown]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🔎 **3.4 Detect and Handle Anomalies/Outliers (revisit if necessary)**
#
# </div>

# %% [markdown]
# * **Identify images that are extremely blurry, too dark/bright, or mislabeled.**
#
# #### **Your Project Notes:**
#
# * **Anomalies Found:** TFDS datasets are usually curated, so severe anomalies (e.g., corrupted files, non-dog images) are rare. However, some images might be low resolution or partially obscured, which the model will have to learn to handle.
# * **Handling Strategy:** Data augmentation is a primary strategy to make the model robust to variations. For critically mislabeled or severely corrupted images, manual review and removal might be necessary in a production pipeline, but not done for this standard dataset.
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## ***Phase 4: Model Selection and Training*** 🧠
#
# > _This phase involves choosing appropriate algorithms, training them on the prepared data, and tuning their parameters._
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🧠 **4.1 Choose Appropriate Algorithms**
#
# </div>

# %% [markdown]
# * **Based on the problem type and data characteristics.**
# * **Consider simplicity first before moving to more complex models.**
#
# #### **Your Project Notes:**
#
# * **[Model 1: e.g., Logistic Regression (Baseline)]**
# * **[Model 2: e.g., RandomForestClassifier]**
# * **[Model 3: e.g., GradientBoostingClassifier (XGBoost/LightGBM)]**
# * **[Model 4: e.g., SVM, Neural Network (if justified)]**
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🧠 **4.2 Train Models**
#
# </div>

# %% [markdown]
# * **Fit chosen algorithms to the training data.**
#
# #### **Your Project Code & Details:**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications
import tensorflow_datasets as tfds

# Define the base model for transfer learning
# Using MobileNetV2 as a good balance of performance and efficiency
# include_top=False removes the classification head, allowing us to add our own.
# pooling='avg' adds a GlobalAveragePooling2D layer, which is common for classification.
base_model = applications.MobileNetV2(input_shape=IMG_SIZE + (3,),
                                       include_top=False,
                                       weights='imagenet',
                                       pooling='avg',
                                       alpha=0.75  # Smaller model for speed (0.35–1.0)
                                       ) # Add GlobalAveragePooling2D

# Freeze the base model layers (initial training phase)
base_model.trainable = False

# Build the classification head
inputs = tf.keras.Input(shape=IMG_SIZE + (3,))
x = base_model(inputs, training=False) # Important for batch_norm layers in base_model
x = layers.Dropout(0.2)(x) # Add dropout for regularization
outputs = layers.Dense(num_classes, activation='softmax')(x) # Output layer for multi-class classification

model = models.Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', # Use sparse_categorical_crossentropy if labels are integers
              metrics=['accuracy',
                        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top_5_accuracy')])

model.summary()

# Train the model (initial phase - fine-tuning only the top layers)
print("\nTraining the model (fine-tuning classification head only)...")
initial_epochs = 5  # Reduce for speed
history_initial = model.fit(ds_train,
                            epochs=initial_epochs,
                            validation_data=ds_val)

# --- Fine-tuning phase (unfreeze some layers of the base model) ---
print("\nStarting fine-tuning of the base model...")
base_model.trainable = True # Unfreeze base model

# Freeze all layers except for the last few blocks in the base model
# This strategy is common to avoid destroying early feature detectors.
# Example: Unfreeze layers from a specific layer onwards (e.g., last ~20 layers)
fine_tune_at = len(base_model.layers) - 30 # Adjust based on model architecture, MobileNetV2 has ~150 layers
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# Recompile the model with a lower learning rate for fine-tuning
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), # Smaller learning rate
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy',
                        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top_5_accuracy')])

fine_tune_epochs = 5
total_epochs = initial_epochs + fine_tune_epochs

history_fine_tune = model.fit(ds_train,
                              epochs=total_epochs,
                              initial_epoch=history_initial.epoch[-1],
                              validation_data=ds_val)

print("\nModel training complete.")

# %% [markdown]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🧠 **4.3 Hyperparameter Tuning**
#
# </div>

# %% [markdown]
# * **Optimize model performance by adjusting hyperparameters.**
# * **Use techniques like Grid Search, Random Search, or Bayesian Optimization.**
#
# #### **Your Project Code & Details:**

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Example: Hyperparameter tuning for Random Forest
print("\nPerforming Hyperparameter Tuning for Random Forest...")

# Define parameter grid
param_grid_rf = {
    'classifier__n_estimators': [100, 200, 300],
    'classifier__max_depth': [None, 10, 20],
    'classifier__min_samples_split': [2, 5]
}

# Use GridSearchCV (can be replaced with RandomizedSearchCV for larger search spaces)
grid_search_rf = GridSearchCV(trained_models['Random Forest'], param_grid_rf, cv=3, scoring='f1', n_jobs=-1, verbose=1)
grid_search_rf.fit(X_train, y_train)

print(f"\nBest parameters for Random Forest: {grid_search_rf.best_params_}")
print(f"Best F1-score on training set for Random Forest: {grid_search_rf.best_score_:.4f}")

# Update the trained model with the best estimator
trained_models['Random Forest (Tuned)'] = grid_search_rf.best_estimator_

# Perform tuning for other models as well
# param_grid_lr = {
#     'classifier__C': [0.01, 0.1, 1, 10, 100]
# }
# grid_search_lr = GridSearchCV(trained_models['Logistic Regression'], param_grid_lr, cv=3, scoring='f1', n_jobs=-1, verbose=1)
# grid_search_lr.fit(X_train, y_train)
# print(f"Best parameters for Logistic Regression: {grid_search_lr.best_params_}")
# trained_models['Logistic Regression (Tuned)'] = grid_search_lr.best_estimator_

# %% [markdown]
# * **Tuning Strategy:** [e.g., "Used GridSearchCV with 3-fold cross-validation, optimizing for F1-score."]
# * **Best Hyperparameters Found:** [List the best parameters for your chosen models]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🧠 **4.4 Cross-Validation**
#
# </div>

# %% [markdown]
# * **Use techniques like k-fold cross-validation to get a more robust estimate of model performance.**
#
# #### **Your Project Notes:**
#
# * **Cross-Validation Details:** [e.g., "Performed 5-fold stratified cross-validation on the training set during hyperparameter tuning."]
# * **Observed Stability:** [Comment on the stability of scores across folds.]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## ***Phase 5: Model Evaluation*** ⭐
#
# > _Evaluate the performance of the trained models using the defined success metrics on unseen data._
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### ⭐ **5.1 Evaluate on Validation Set (if applicable)**
#
# </div>

# %% [markdown]
# * **Use the validation set to compare different models and fine-tune hyperparameters.**
#
# #### **Your Project Code & Details:**

# %%
# Evaluate all trained models on the validation set
results = {}
for name, model in trained_models.items():
    y_pred_val = model.predict(X_val)
    y_prob_val = model.predict_proba(X_val)[:, 1] # Probability for the positive class

    accuracy = accuracy_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    recall = recall_score(y_val, y_pred_val)
    f1 = f1_score(y_val, y_pred_val)
    roc_auc = roc_auc_score(y_val, y_prob_val)

    results[name] = {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1-Score': f1,
        'ROC AUC': roc_auc
    }
    print(f"\n--- {name} Validation Metrics ---")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print(f"ROC AUC: {roc_auc:.4f}")

# Convert results to a DataFrame for easy comparison
results_df = pd.DataFrame(results).T
print("\nModel Performance on Validation Set:")
print(results_df)

# Based on validation set, choose the best model for final evaluation
best_model_name_val = results_df['ROC AUC'].idxmax() # Or another metric based on your goal
final_model = trained_models[best_model_name_val]
print(f"\nBest model based on validation ROC AUC: {best_model_name_val}")

# %% [markdown]
# * **Validation Set Performance Summary:** [Summarize key metrics and insights.]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### ⭐ **5.2 Evaluate on Test Set**
#
# </div>

# %% [markdown]
# * **Use the completely unseen test set to get an unbiased estimate of the model's generalization performance.**
# * **Calculate chosen metrics, generate confusion matrices.**
#
# #### **Your Project Code & Details:**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

print(f"\n--- Evaluating Final Model ({best_model_name_val}) on Test Set ---")

y_pred_test = final_model.predict(X_test)
y_prob_test = final_model.predict_proba(X_test)[:, 1]

test_accuracy = accuracy_score(y_test, y_pred_test)
test_precision = precision_score(y_test, y_pred_test)
test_recall = recall_score(y_test, y_pred_test)
test_f1 = f1_score(y_test, y_pred_test)
test_roc_auc = roc_auc_score(y_test, y_prob_test)

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
print(f"Test F1-Score: {test_f1:.4f}")
print(f"Test ROC AUC: {test_roc_auc:.4f}")

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=final_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Confusion Matrix for {best_model_name_val} on Test Set')
plt.show()

# ROC Curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_test)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {test_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic for {best_model_name_val}')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# * **Test Set Performance Summary:** [Final reported metrics and interpretation.]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### ⭐ **5.3 Interpret Model Results**
#
# </div>

# %% [markdown]
# * **Understand why the model is making certain predictions (e.g., feature importance, SHAP values, LIME).**
#
# #### **Your Project Code & Details:**

# %%
# Example: Feature Importance for tree-based models
if hasattr(final_model.named_steps['classifier'], 'feature_importances_'):
    feature_importances = final_model.named_steps['classifier'].feature_importances_
    # Get feature names after one-hot encoding if applicable
    ohe_feature_names = final_model.named_steps['preprocessor'].named_transformers_['cat'].get_feature_names_out(categorical_features_final)
    all_feature_names = numerical_features_final + list(ohe_feature_names) # Combine feature names

    importance_df = pd.DataFrame({
        'Feature': all_feature_names,
        'Importance': feature_importances
    }).sort_values(by='Importance', ascending=False)

    print("\nTop 10 Feature Importances:")
    print(importance_df.head(10))

    plt.figure(figsize=(10, 6))
    sns.barplot(x='Importance', y='Feature', data=importance_df.head(10))
    plt.title('Top 10 Feature Importances')
    plt.show()

# If using more complex models, consider libraries like SHAP or LIME
# import shap
# explainer = shap.TreeExplainer(final_model.named_steps['classifier'])
# shap_values = explainer.shap_values(preprocessor_final.transform(X_test))
# shap.summary_plot(shap_values, preprocessor_final.transform(X_test), feature_names=all_feature_names)

# %% [markdown]
# * **Key Findings from Interpretation:** [e.g., "Customer tenure and monthly charges are the most influential features for churn prediction."]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### ⭐ **5.4 Compare Models**
#
# </div>

# %% [markdown]
# * **If multiple models were trained, compare their performance and choose the best one.**
#
# #### **Your Project Notes:**
#
# * **Final Model Choice:** [State which model was chosen and why (e.g., "Gradient Boosting Classifier chosen due to superior F1-score and AUC on the test set, balancing precision and recall.")]
# * **Trade-offs:** [Discuss any trade-offs considered, e.g., "Logistic Regression was faster but less accurate, while Gradient Boosting offered better performance at the cost of interpretability."]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## ***Phase 6: Deployment*** 🚀
#
# > _Making the model available for practical use, often in a production environment._
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🚀 **6.1 Model Serialization**
#
# </div>

# %% [markdown]
# * **Save the trained model in a deployable format.**
#
# #### **Your Project Code & Details:**

# %%
import joblib
import os

# Create a directory for saving the model
MODEL_DIR = 'model_artifacts'
os.makedirs(MODEL_DIR, exist_ok=True)

# Save the final model (the entire pipeline if using one)
model_path = os.path.join(MODEL_DIR, 'final_ml_model.joblib')
joblib.dump(final_model, model_path)
print(f"Model saved to: {model_path}")

# To load the model later:
# loaded_model = joblib.load(model_path)

# %% [markdown]
# * **Serialization Format:** [e.g., "joblib"]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🚀 **6.2 API Development (if applicable)**
#
# </div>

# %% [markdown]
# * **Wrap the model in a RESTful API for easy integration.**
#
# #### **Your Project Notes & Pseudocode:**

# %%
# Example of a simple Flask API structure (pseudocode)
# from flask import Flask, request, jsonify
# import joblib
#
# app = Flask(__name__)
#
# # Load the model when the app starts
# model = joblib.load('model_artifacts/final_ml_model.joblib')
#
# @app.route('/predict', methods=['POST'])
# def predict():
#     data = request.get_json(force=True)
#     # Assuming data is a dictionary matching your feature schema
#     input_df = pd.DataFrame([data])
#     prediction = model.predict(input_df)[0]
#     probability = model.predict_proba(input_df)[0].tolist()
#     return jsonify({'prediction': int(prediction), 'probability': probability})
#
# if __name__ == '__main__':
#     app.run(debug=True, host='0.0.0.0', port=5000)

# %% [markdown]
# * **API Framework:** [e.g., Flask, FastAPI]
# * **Endpoint Details:** [e.g., /predict for POST requests, expected JSON payload.]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🚀 **6.3 Deployment Environment**
#
# </div>

# %% [markdown]
# * **Deploy the model to a production environment.**
# * **Consider containerization (Docker, Kubernetes).**
#
# #### **Your Project Details:**
#
# * **Deployment Platform:** [e.g., AWS Sagemaker, Google Cloud AI Platform, Azure ML, Kubernetes cluster, local server]
# * **Containerization Strategy:** [e.g., "Docker image created for the Flask API."]
# * **Key Environment Variables/Configurations:** [List crucial environment variables]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🚀 **6.4 Infrastructure Setup**
#
# </div>

# %% [markdown]
# * **Set up necessary infrastructure for model serving, scalability, and monitoring.**
#
# #### **Your Project Details:**
#
# * **Infrastructure Components:** [e.g., Load balancer, auto-scaling groups, database connections for real-time data.]
# * **Scaling Strategy:** [e.g., "Auto-scaling based on CPU utilization."]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## ***Phase 7: Monitoring and Maintenance*** 🛠️
#
# > _Machine learning models are not "set and forget." They require continuous monitoring and periodic updates._
#
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🛠️ **7.1 Monitor Model Performance**
#
# </div>

# %% [markdown]
# * **Track key performance metrics in real-time.**
# * **Set up alerts for performance degradation.**
#
# #### **Your Project Details:**
#
# * **Monitoring Tools:** [e.g., Prometheus, Grafana, AWS CloudWatch, custom dashboards.]
# * **Metrics Tracked:** [e.g., Accuracy, F1-score (re-calculated on live data), latency, request throughput.]
# * **Alerting Mechanism:** [e.g., Slack notifications if F1-score drops below X for Y hours.]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🛠️ **7.2 Monitor Data Drift**
#
# </div>

# %% [markdown]
# * **Detect changes in the distribution of input data over time.**
#
# #### **Your Project Details:**
#
# * **Drift Detection Method:** [e.g., Kolmogorov-Smirnov test, Population Stability Index (PSI), adversarial validation.]
# * **Drift Triggers:** [e.g., "If distribution of 'customer_age' changes significantly (e.g., PSI > 0.1) trigger an alert."]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🛠️ **7.3 Retraining Strategy**
#
# </div>

# %% [markdown]
# * **Establish a schedule or trigger for retraining the model.**
#
# #### **Your Project Details:**
#
# * **Retraining Frequency:** [e.g., "Monthly retrain with the latest 6 months of data."]
# * **Retraining Triggers:** [e.g., "Retrain if model performance drops by 5% on live data, or if significant data drift is detected."]
# * **Automated Pipeline:** [e.g., "CI/CD pipeline for automated retraining and deployment."]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🛠️ **7.4 Model Versioning**
#
# </div>

# %% [markdown]
# * **Maintain different versions of models and track their performance.**
#
# #### **Your Project Details:**
#
# * **Versioning System:** [e.g., MLflow, DVC (Data Version Control), custom naming conventions.]
# * **Rollback Plan:** [e.g., "Ability to roll back to previous model version if new deployment fails or underperforms."]
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### 🛠️ **7.5 Logging and Auditing**
#
# </div>

# %% [markdown]
# * **Log model predictions, inputs, and outputs for debugging and auditing.**
#
# #### **Your Project Details:**
#
# * **Logging Strategy:** [e.g., "Log all prediction requests and responses to a dedicated log sink (e.g., Stackdriver, Splunk)."]
# * **Audit Trail:** [e.g., "Ensure PII is masked in logs; maintain an audit trail of model updates and deployments."]
# ---
